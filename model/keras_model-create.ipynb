# %% [markdown]
# ### kerasで学習済データの保存

# %%
from sklearn import datasets
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.utils.np_utils import to_categorical

# アヤメのサンプルデータの読み込み
iris = datasets.load_iris()
in_size = 4
nb_classes=3
# ラベルデータをone-hotベクトルに直す
x = iris.data
y = to_categorical(iris.target, nb_classes)

# モデルを定義
model = Sequential()
model.add(Dense(512, activation='relu', input_shape=(in_size,)))
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(nb_classes, activation='softmax'))
# コンパイル
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
# 学習を実行
model.fit(x, y, batch_size=20, epochs=50)

# モデルを保存
model.save('iris_model.h5')
# 学習済重みデータを保存
model.save_weights('iris_weight.h5')
# Out:
# Epoch 1/50
# 150/150 [==============================] - 1s 5ms/step - loss: 0.9181 - accuracy: 0.5533
# Epoch 2/50
# 150/150 [==============================] - 0s 396us/step - loss: 0.5238 - accuracy: 0.7600
# Epoch 3/50
# 150/150 [==============================] - 0s 373us/step - loss: 0.3948 - accuracy: 0.8200
# Epoch 4/50
# 150/150 [==============================] - 0s 357us/step - loss: 0.3210 - accuracy: 0.8667
# Epoch 5/50
# 150/150 [==============================] - 0s 364us/step - loss: 0.2382 - accuracy: 0.9333
# Epoch 6/50
# 150/150 [==============================] - 0s 354us/step - loss: 0.2128 - accuracy: 0.9333
# Epoch 7/50
# 150/150 [==============================] - 0s 350us/step - loss: 0.1890 - accuracy: 0.9400
# Epoch 8/50
# 150/150 [==============================] - 0s 367us/step - loss: 0.1565 - accuracy: 0.9467
# Epoch 9/50
# 150/150 [==============================] - 0s 353us/step - loss: 0.1506 - accuracy: 0.9400
# Epoch 10/50
# 150/150 [==============================] - 0s 359us/step - loss: 0.1870 - accuracy: 0.9333
# Epoch 11/50
# 150/150 [==============================] - 0s 363us/step - loss: 0.1398 - accuracy: 0.9333
# Epoch 12/50
# 150/150 [==============================] - 0s 347us/step - loss: 0.1064 - accuracy: 0.9600
# Epoch 13/50
# 150/150 [==============================] - 0s 354us/step - loss: 0.1069 - accuracy: 0.9667
# Epoch 14/50
# 150/150 [==============================] - 0s 358us/step - loss: 0.1261 - accuracy: 0.9400
# Epoch 15/50
# 150/150 [==============================] - 0s 359us/step - loss: 0.0910 - accuracy: 0.9667
# Epoch 16/50
# 150/150 [==============================] - 0s 406us/step - loss: 0.0880 - accuracy: 0.9733
# Epoch 17/50
# 150/150 [==============================] - 0s 379us/step - loss: 0.0954 - accuracy: 0.9733
# Epoch 18/50
# 150/150 [==============================] - 0s 367us/step - loss: 0.0890 - accuracy: 0.9667
# Epoch 19/50
# 150/150 [==============================] - 0s 374us/step - loss: 0.0734 - accuracy: 0.9800
# Epoch 20/50
# 150/150 [==============================] - 0s 378us/step - loss: 0.1111 - accuracy: 0.9600
# Epoch 21/50
# 150/150 [==============================] - 0s 381us/step - loss: 0.0764 - accuracy: 0.9667
# Epoch 22/50
# 150/150 [==============================] - 0s 393us/step - loss: 0.0748 - accuracy: 0.9800
# Epoch 23/50
# 150/150 [==============================] - 0s 385us/step - loss: 0.0848 - accuracy: 0.9667
# Epoch 24/50
# 150/150 [==============================] - 0s 393us/step - loss: 0.0820 - accuracy: 0.9667
# Epoch 25/50
# 150/150 [==============================] - 0s 380us/step - loss: 0.1100 - accuracy: 0.9533
# Epoch 26/50
# 150/150 [==============================] - 0s 398us/step - loss: 0.1270 - accuracy: 0.9467
# Epoch 27/50
# 150/150 [==============================] - 0s 397us/step - loss: 0.2309 - accuracy: 0.9133
# Epoch 28/50
# 150/150 [==============================] - 0s 378us/step - loss: 0.0936 - accuracy: 0.9533
# Epoch 29/50
# 150/150 [==============================] - 0s 395us/step - loss: 0.0747 - accuracy: 0.9800
# Epoch 30/50
# 150/150 [==============================] - 0s 379us/step - loss: 0.0850 - accuracy: 0.9667
# Epoch 31/50
# 150/150 [==============================] - 0s 409us/step - loss: 0.0815 - accuracy: 0.9533
# Epoch 32/50
# 150/150 [==============================] - 0s 401us/step - loss: 0.0790 - accuracy: 0.9600
# Epoch 33/50
# 150/150 [==============================] - 0s 390us/step - loss: 0.0887 - accuracy: 0.9600
# Epoch 34/50
# 150/150 [==============================] - 0s 393us/step - loss: 0.0917 - accuracy: 0.9533
# Epoch 35/50
# 150/150 [==============================] - 0s 407us/step - loss: 0.0631 - accuracy: 0.9800
# Epoch 36/50
# 150/150 [==============================] - 0s 382us/step - loss: 0.0895 - accuracy: 0.9600
# Epoch 37/50
# 150/150 [==============================] - 0s 404us/step - loss: 0.0719 - accuracy: 0.9733
# Epoch 38/50
# 150/150 [==============================] - 0s 385us/step - loss: 0.0763 - accuracy: 0.9800
# Epoch 39/50
# 150/150 [==============================] - 0s 377us/step - loss: 0.0647 - accuracy: 0.9800
# Epoch 40/50
# 150/150 [==============================] - 0s 397us/step - loss: 0.0866 - accuracy: 0.9600
# Epoch 41/50
# 150/150 [==============================] - 0s 385us/step - loss: 0.1223 - accuracy: 0.9533
# Epoch 42/50
# 150/150 [==============================] - 0s 387us/step - loss: 0.0948 - accuracy: 0.9600
# Epoch 43/50
# 150/150 [==============================] - 0s 388us/step - loss: 0.0976 - accuracy: 0.9667
# Epoch 44/50
# 150/150 [==============================] - 0s 378us/step - loss: 0.0999 - accuracy: 0.9600
# Epoch 45/50
# 150/150 [==============================] - 0s 433us/step - loss: 0.1112 - accuracy: 0.9400
# Epoch 46/50
# 150/150 [==============================] - 0s 385us/step - loss: 0.1113 - accuracy: 0.9533
# Epoch 47/50
# 150/150 [==============================] - 0s 378us/step - loss: 0.0971 - accuracy: 0.9533
# Epoch 48/50
# 150/150 [==============================] - 0s 403us/step - loss: 0.1349 - accuracy: 0.9667
# Epoch 49/50
# 150/150 [==============================] - 0s 393us/step - loss: 0.0814 - accuracy: 0.9533
# Epoch 50/50
# 150/150 [==============================] - 0s 365us/step - loss: 0.0680 - accuracy: 0.9733

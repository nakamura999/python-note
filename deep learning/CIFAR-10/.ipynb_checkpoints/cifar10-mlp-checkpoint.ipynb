# %%
import matplotlib.pyplot as plt
import keras
from keras.datasets import cifar10
from keras.models import Sequential
from keras.layers import Dense, Dropout

num_classes = 10
im_rows =32
im_clos = 32
im_size = im_rows * im_clos * 3

# データを読み込み
(X_train, y_train), (X_test, y_test) = cifar10.load_data()

# データを一次元配列に変換
X_train = X_train.reshape(-1, im_size).astype('float32') / 255
X_test = X_test.reshape(-1, im_size).astype('float32') / 255
# ラベルデータをOne-Hot形式に変換
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# モデルを定義
model = Sequential()
model.add(Dense(512, activation='relu', input_shape=(im_size,)))
model.add(Dense(num_classes, activation='softmax'))

# モデルをコンパイル
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# 学習を実行
hist = model.fit(X_train, y_train, batch_size=32, epochs=50, verbose=1, validation_data=(X_test, y_test))

# モデルを評価
score = model.evaluate(X_test, y_test, verbose=1)
print('正解率=', score[1], 'loss=', score[0])

# 学習の様子をグラフへ出力
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('Accuracy')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Loss')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 36s 718us/step - loss: 1.8879 - accuracy: 0.3262 - val_loss: 1.7355 - val_accuracy: 0.3725
# Epoch 2/50
# 50000/50000 [==============================] - 37s 733us/step - loss: 1.7067 - accuracy: 0.3927 - val_loss: 1.6766 - val_accuracy: 0.3978
# Epoch 3/50
# 50000/50000 [==============================] - 36s 725us/step - loss: 1.6496 - accuracy: 0.4148 - val_loss: 1.6788 - val_accuracy: 0.4091
# Epoch 4/50
# 50000/50000 [==============================] - 35s 708us/step - loss: 1.6057 - accuracy: 0.4267 - val_loss: 1.6029 - val_accuracy: 0.4247
# Epoch 5/50
# 50000/50000 [==============================] - 35s 708us/step - loss: 1.5729 - accuracy: 0.4389 - val_loss: 1.5446 - val_accuracy: 0.4489
# Epoch 6/50
# 50000/50000 [==============================] - 36s 710us/step - loss: 1.5501 - accuracy: 0.4477 - val_loss: 1.5461 - val_accuracy: 0.4482
# Epoch 7/50
# 50000/50000 [==============================] - 35s 709us/step - loss: 1.5317 - accuracy: 0.4553 - val_loss: 1.5542 - val_accuracy: 0.4484
# Epoch 8/50
# 50000/50000 [==============================] - 36s 711us/step - loss: 1.5146 - accuracy: 0.4599 - val_loss: 1.5872 - val_accuracy: 0.4371
# Epoch 9/50
# 50000/50000 [==============================] - 35s 708us/step - loss: 1.5021 - accuracy: 0.4666 - val_loss: 1.5283 - val_accuracy: 0.4577
# Epoch 10/50
# 50000/50000 [==============================] - 36s 710us/step - loss: 1.4910 - accuracy: 0.4680 - val_loss: 1.5183 - val_accuracy: 0.4574
# Epoch 11/50
# 50000/50000 [==============================] - 35s 708us/step - loss: 1.4839 - accuracy: 0.4739 - val_loss: 1.5227 - val_accuracy: 0.4645
# Epoch 12/50
# 50000/50000 [==============================] - 35s 709us/step - loss: 1.4695 - accuracy: 0.4777 - val_loss: 1.5274 - val_accuracy: 0.4525
# Epoch 13/50
# 50000/50000 [==============================] - 36s 711us/step - loss: 1.4629 - accuracy: 0.4798 - val_loss: 1.5567 - val_accuracy: 0.4521
# Epoch 14/50
# 50000/50000 [==============================] - 36s 713us/step - loss: 1.4578 - accuracy: 0.4780 - val_loss: 1.5053 - val_accuracy: 0.4669
# Epoch 15/50
# 50000/50000 [==============================] - 36s 725us/step - loss: 1.4483 - accuracy: 0.4833 - val_loss: 1.5174 - val_accuracy: 0.4685
# Epoch 16/50
# 50000/50000 [==============================] - 36s 711us/step - loss: 1.4428 - accuracy: 0.4855 - val_loss: 1.5178 - val_accuracy: 0.4593
# Epoch 17/50
# 50000/50000 [==============================] - 36s 717us/step - loss: 1.4346 - accuracy: 0.4879 - val_loss: 1.5225 - val_accuracy: 0.4630
# Epoch 18/50
# 50000/50000 [==============================] - 36s 726us/step - loss: 1.4284 - accuracy: 0.4888 - val_loss: 1.5393 - val_accuracy: 0.4574
# Epoch 19/50
# 50000/50000 [==============================] - 36s 718us/step - loss: 1.4227 - accuracy: 0.4924 - val_loss: 1.5057 - val_accuracy: 0.4698
# Epoch 20/50
# 50000/50000 [==============================] - 36s 716us/step - loss: 1.4160 - accuracy: 0.4942 - val_loss: 1.5018 - val_accuracy: 0.4679
# Epoch 21/50
# 50000/50000 [==============================] - 36s 719us/step - loss: 1.4099 - accuracy: 0.4970 - val_loss: 1.5168 - val_accuracy: 0.4631
# Epoch 22/50
# 50000/50000 [==============================] - 36s 724us/step - loss: 1.4078 - accuracy: 0.4993 - val_loss: 1.4967 - val_accuracy: 0.4723
# Epoch 23/50
# 50000/50000 [==============================] - 36s 729us/step - loss: 1.3992 - accuracy: 0.5009 - val_loss: 1.5100 - val_accuracy: 0.4703
# Epoch 24/50
# 50000/50000 [==============================] - 36s 719us/step - loss: 1.4018 - accuracy: 0.5012 - val_loss: 1.4996 - val_accuracy: 0.4655
# Epoch 25/50
# 50000/50000 [==============================] - 35s 708us/step - loss: 1.3924 - accuracy: 0.5032 - val_loss: 1.5329 - val_accuracy: 0.4583
# Epoch 26/50
# 50000/50000 [==============================] - 36s 716us/step - loss: 1.3935 - accuracy: 0.5017 - val_loss: 1.5076 - val_accuracy: 0.4678
# Epoch 27/50
# 50000/50000 [==============================] - 36s 719us/step - loss: 1.3857 - accuracy: 0.5060 - val_loss: 1.5088 - val_accuracy: 0.4701
# Epoch 28/50
# 50000/50000 [==============================] - 36s 718us/step - loss: 1.3828 - accuracy: 0.5068 - val_loss: 1.5265 - val_accuracy: 0.4640
# Epoch 29/50
# 50000/50000 [==============================] - 36s 719us/step - loss: 1.3763 - accuracy: 0.5084 - val_loss: 1.5145 - val_accuracy: 0.4689
# Epoch 30/50
# 50000/50000 [==============================] - 36s 721us/step - loss: 1.3729 - accuracy: 0.5086 - val_loss: 1.5866 - val_accuracy: 0.4476
# Epoch 31/50
# 50000/50000 [==============================] - 37s 732us/step - loss: 1.3707 - accuracy: 0.5103 - val_loss: 1.4846 - val_accuracy: 0.4753
# Epoch 32/50
# 50000/50000 [==============================] - 36s 723us/step - loss: 1.3636 - accuracy: 0.5123 - val_loss: 1.4988 - val_accuracy: 0.4792
# Epoch 33/50
# 50000/50000 [==============================] - 36s 723us/step - loss: 1.3673 - accuracy: 0.5094 - val_loss: 1.5337 - val_accuracy: 0.4575
# Epoch 34/50
# 50000/50000 [==============================] - 36s 726us/step - loss: 1.3650 - accuracy: 0.5115 - val_loss: 1.4950 - val_accuracy: 0.4761
# Epoch 35/50
# 50000/50000 [==============================] - 36s 723us/step - loss: 1.3589 - accuracy: 0.5150 - val_loss: 1.5298 - val_accuracy: 0.4644
# Epoch 36/50
# 50000/50000 [==============================] - 38s 763us/step - loss: 1.3531 - accuracy: 0.5150 - val_loss: 1.4840 - val_accuracy: 0.4766
# Epoch 37/50
# 50000/50000 [==============================] - 37s 747us/step - loss: 1.3546 - accuracy: 0.5162 - val_loss: 1.4948 - val_accuracy: 0.4697
# Epoch 38/50
# 50000/50000 [==============================] - 36s 727us/step - loss: 1.3514 - accuracy: 0.5183 - val_loss: 1.4904 - val_accuracy: 0.4776
# Epoch 39/50
# 50000/50000 [==============================] - 36s 728us/step - loss: 1.3492 - accuracy: 0.5176 - val_loss: 1.4879 - val_accuracy: 0.4813
# Epoch 40/50
# 50000/50000 [==============================] - 36s 724us/step - loss: 1.3423 - accuracy: 0.5198 - val_loss: 1.5109 - val_accuracy: 0.4778
# Epoch 41/50
# 50000/50000 [==============================] - 37s 730us/step - loss: 1.3364 - accuracy: 0.5222 - val_loss: 1.4872 - val_accuracy: 0.4770
# Epoch 42/50
# 50000/50000 [==============================] - 36s 719us/step - loss: 1.3381 - accuracy: 0.5215 - val_loss: 1.5232 - val_accuracy: 0.4674
# Epoch 43/50
# 50000/50000 [==============================] - 36s 719us/step - loss: 1.3380 - accuracy: 0.5218 - val_loss: 1.4960 - val_accuracy: 0.4800
# Epoch 44/50
# 50000/50000 [==============================] - 36s 721us/step - loss: 1.3302 - accuracy: 0.5233 - val_loss: 1.6037 - val_accuracy: 0.4506
# Epoch 45/50
# 50000/50000 [==============================] - 36s 720us/step - loss: 1.3321 - accuracy: 0.5240 - val_loss: 1.5174 - val_accuracy: 0.4715
# Epoch 46/50
# 50000/50000 [==============================] - 36s 721us/step - loss: 1.3267 - accuracy: 0.5254 - val_loss: 1.4885 - val_accuracy: 0.4800
# Epoch 47/50
# 50000/50000 [==============================] - 39s 772us/step - loss: 1.3234 - accuracy: 0.5249 - val_loss: 1.5240 - val_accuracy: 0.4759
# Epoch 48/50
# 50000/50000 [==============================] - 37s 747us/step - loss: 1.3227 - accuracy: 0.5264 - val_loss: 1.4997 - val_accuracy: 0.4699
# Epoch 49/50
# 50000/50000 [==============================] - 36s 721us/step - loss: 1.3182 - accuracy: 0.5273 - val_loss: 1.5144 - val_accuracy: 0.4654
# Epoch 50/50
# 50000/50000 [==============================] - 36s 711us/step - loss: 1.3203 - accuracy: 0.5270 - val_loss: 1.5174 - val_accuracy: 0.4646
# 10000/10000 [==============================] - 1s 69us/step
# 正解率= 0.46459999680519104 loss= 1.517425383758545
